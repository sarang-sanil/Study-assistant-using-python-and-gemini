# %% [markdown]
# <a href="https://colab.research.google.com/github/sarang-sanil/Study-assistant-using-python-and-gemini/blob/main/Study_assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
from google import genai

# %%
from google.colab import userdata

# %%
api_key = userdata.get("GEMINI_API_KEY")

# %%
client = genai.Client(api_key=api_key)

# %%
def study_assistant(user_prompt):
  response = client.models.generate_content (
  model = "gemini-2.5-flash",
  contents = user_prompt)
  return response

# %% [markdown]
# text is used for only output no metadata

# %%
output = study_assistant("explain gen ai")
print(output.text)
# Out:
# **Generative AI** is a type of artificial intelligence that can **create new and original content** based on patterns it has learned from vast amounts of existing data. Unlike traditional AI that primarily classifies, predicts, or analyzes (e.g., telling you if an image contains a cat, or predicting stock prices), Generative AI *produces* something entirely new.
#
# Think of it like a highly skilled apprentice who has studied millions of paintings, books, songs, or pieces of code. Once trained, you can give this apprentice a simple instruction (a "prompt"), and they can then create a brand new piece of art, write an original story, compose a unique melody, or generate functional code, all in a style consistent with what they've learned.
#
# ---
#
# Here's a breakdown of what that means:
#
# 1.  **"Generative" - The Core Idea:**
#     *   It doesn't just retrieve information or modify existing content. It generates *novel* outputs.
# ...
